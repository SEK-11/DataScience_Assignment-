# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250
sns.set_style('darkgrid')
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train=pd.read_csv('https://raw.githubusercontent.com/SEK-11/dataset_excelR/main/DATA/SalaryData_Train(1).csv')

# %%
df_test=pd.read_csv('https://github.com/SEK-11/dataset_excelR/blob/main/DATA/SalaryData_Test(1).csv')

# %%
df_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
df_train.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
df_train['capitalgain'].unique()
# Out:
# array([ 2174,     0, 14084,  5178,  5013,  2407, 14344, 15024,  7688,
#         4064,  4386,  7298,  1409,  3674,  1055,  2050,  2176,   594,
#        20051,  6849,  4101,  8614,  3411,  2597, 25236,  4650,  2463,
#         3103, 10605,  2964,  3325,  2580,  3471,  4865, 99999,  6514,
#         1471,  2329,  2105,  2885, 10520,  2202,  2961, 27828,  6767,
#         2228,  1506, 13550,  2635,  5556,  4787,  3781,  3137,  3818,
#          914,   401,  2829,  2977,  4934,  2062,  2354,  3464,  5455,
#        15020,  1424,  3273, 22040,  4416, 10566,  4931,  7430, 34095,
#         6497,  3908,   114,  2346,  2907,  1151,  9386,  2414,  2290,
#         3418, 15831, 41310,  4508,  2538,  3456,  1848,  3887,  7896,
#         5721,  9562,  6418,  1455,  2036,  3942,  1831, 11678,  2936,
#         2993,  7443,  6360,  4687,  1797,  6723,  2009,  3432,  6097,
#         1639,  2653, 18481, 25124,  7978,   991,  1173,  2387,  5060,
#         1086], dtype=int64)

# %%
df_train['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' 7th-8th', ' Doctorate',
#        ' Assoc-voc', ' Prof-school', ' 5th-6th', ' 10th', ' Preschool',
#        ' 12th', ' 1st-4th'], dtype=object)

# %%
df_train.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
df_train.duplicated().sum()
# Out:
# 3258

# %%
df_train[df_train.duplicated(keep=False)]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 12      23   Private      Bachelors           13        Never-married
# 16      32   Private        HS-grad            9        Never-married
# 19      40   Private      Doctorate           16   Married-civ-spouse
# 25      19   Private        HS-grad            9        Never-married
# 27      49   Private        HS-grad            9   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 30110   47   Private        HS-grad            9   Married-civ-spouse
# 30118   20   Private        HS-grad            9        Never-married
# 30132   22   Private   Some-college           10        Never-married
# 30157   40   Private        HS-grad            9   Married-civ-spouse
# 30159   22   Private        HS-grad            9        Never-married
#
#                occupation relationship    race      sex  capitalgain  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
df_train.drop_duplicates(inplace=True)

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.drop(columns=['educationno','race','capitalloss','capitalgain','sex'],inplace=True)

# %%
df_train
# Out:
#        age          workclass      education        maritalstatus  \
# 0       39          State-gov      Bachelors        Never-married
# 1       50   Self-emp-not-inc      Bachelors   Married-civ-spouse
# 2       38            Private        HS-grad             Divorced
# 3       53            Private           11th   Married-civ-spouse
# 4       28            Private      Bachelors   Married-civ-spouse
# ...    ...                ...            ...                  ...
# 30154   53            Private        Masters   Married-civ-spouse
# 30155   22            Private   Some-college        Never-married
# 30156   27            Private     Assoc-acdm   Married-civ-spouse
# 30158   58            Private        HS-grad              Widowed
# 30160   52       Self-emp-inc        HS-grad   Married-civ-spouse
#
#                occupation    relationship  hoursperweek          native  \
# 0            Adm-clerical   Not-in-family            40   United-States
# ...

# %%
df_train['Salary'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df_train['Salary'].replace(' <=50K',0,inplace=True)

# %%
df_train['Salary'].replace(' >50K',1,inplace=True)

# %%
df_train.head(3)
# Out:
#    age          workclass   education        maritalstatus  \
# 0   39          State-gov   Bachelors        Never-married
# 1   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2   38            Private     HS-grad             Divorced
#
#            occupation    relationship  hoursperweek          native  Salary
# 0        Adm-clerical   Not-in-family            40   United-States       0
# 1     Exec-managerial         Husband            13   United-States       0
# 2   Handlers-cleaners   Not-in-family            40   United-States       0

# %%
df_train['Salary'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df_train['Salary'].astype(int)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30154    1
# 30155    0
# 30156    0
# 30158    0
# 30160    1
# Name: Salary, Length: 26903, dtype: int32

# %%
df_train['Salary'] = df_train['Salary'].astype(int)

# %%
df_train.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# maritalstatus    object
# occupation       object
# relationship     object
# hoursperweek      int64
# native           object
# Salary            int32
# dtype: object

# %%
#TESTING DATA

# %%
df_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
df_test.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
df_test.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
df_test.duplicated().sum()
# Out:
# 930

# %%
df_test[df_test.duplicated(keep=False)]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 29      26   Private        HS-grad            9             Divorced
# 33      20   Private        HS-grad            9        Never-married
# 37      29   Private           11th            7   Married-civ-spouse
# 44      18   Private   Some-college           10        Never-married
# 49      21   Private   Some-college           10        Never-married
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation relationship    race      sex  capitalgain  \
# ...

# %%
df_test.drop(columns=['educationno','race','capitalloss','capitalgain','sex'],inplace=True)

# %%
df_test
# Out:
#        age      workclass      education        maritalstatus  \
# 0       25        Private           11th        Never-married
# 1       38        Private        HS-grad   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm   Married-civ-spouse
# 3       44        Private   Some-college   Married-civ-spouse
# 4       34        Private           10th        Never-married
# ...    ...            ...            ...                  ...
# 15055   33        Private      Bachelors        Never-married
# 15056   39        Private      Bachelors             Divorced
# 15057   38        Private      Bachelors   Married-civ-spouse
# 15058   44        Private      Bachelors             Divorced
# 15059   35   Self-emp-inc      Bachelors   Married-civ-spouse
#
#                occupation    relationship  hoursperweek          native  \
# 0       Machine-op-inspct       Own-child            40   United-States
# 1         Farming-fishing         Husband            50   United-States
# ...

# %%
df_test.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# maritalstatus    object
# occupation       object
# relationship     object
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
df_test['Salary'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df_test['Salary'].replace(' >50K',1,inplace=True)

# %%
df_test['Salary'].replace(' <=50K',0,inplace=True)

# %%
df_test['Salary']=df_test["Salary"].astype(int)

# %%
df_test.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# maritalstatus    object
# occupation       object
# relationship     object
# hoursperweek      int64
# native           object
# Salary            int32
# dtype: object

# %%
df_train = pd.get_dummies(data=df_train,columns= ['workclass','education','maritalstatus','occupation','relationship','native'])

# %%
df_test = pd.get_dummies(data=df_test,columns= ['workclass','education','maritalstatus','occupation','relationship','native'])

# %%
xtr = df_train.iloc[:,:-1]
ytr = df_train.iloc[:,-1]

# %%
xte = df_test.iloc[:,:-1]
yte = df_test.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xtr = sc.fit_transform(xtr)         
xte = sc.fit_transform(xte)

# %%
svc = SVC()

svc.fit(xtr,ytr)
ypred = svc.predict(xte)
print(svc.score(xtr,ytr))
print(svc.score(xte,yte))
# Out:
# 0.9999256588484555
# 0.999867197875166
